# %% [markdown]
# # 이상지질혈증 예측 - XGBoost Optuna SHAP 분석
#
# - 타겟: `이상지질혈증유병` (0: 없음 / 1: 있음)
# - 모델: XGBoost (Optuna 최적 파라미터)
# - 데이터: x1_preprocessed.csv
# - 분석: OOF 전체 기준 SHAP 피처 기여도 해석
# - Threshold: 0.45 고정
# - 검증: Stratified 5-Fold CV

# %%
import os
import warnings

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import shap
import xgboost as xgb
from sklearn.metrics import (
    confusion_matrix,
    f1_score,
    precision_score,
    recall_score,
    roc_auc_score,
)
from sklearn.model_selection import StratifiedKFold

warnings.filterwarnings("ignore")
matplotlib.rcParams["font.family"] = "DejaVu Sans"


# ── 경로 설정 ──────────────────────────────────────────────
INPUT_PATH = "/Users/Jiyeon/Desktop/final_project/ML/data/x1_preprocessed.csv"
NPY_DIR = "/Users/Jiyeon/Desktop/final_project/ML/outputs/oof"
RANDOM_STATE = 42
THRESHOLD = 0.45

# %% [markdown]
# ## 1. 데이터 로드

# %%
df = pd.read_csv(INPUT_PATH)
print(f"로드 완료 | shape: {df.shape}")
# Out:
# 로드 완료 | shape: (6033, 32)

# %% [markdown]
# ## 2. 피처 / 타겟 분리

# %%
TARGET = "이상지질혈증유병"
DROP_COLS = ["고혈압유병", "당뇨유병", "이상지질혈증유병", "비만단계"]

data = df.dropna(subset=[TARGET]).copy()
X = data.drop(columns=DROP_COLS)
y = data[TARGET].astype(int)
neg, pos = (y == 0).sum(), (y == 1).sum()
ratio = neg / pos
print(f"샘플 수: {len(y)}  |  정상: {neg}  |  이상지질혈증: {pos}")
# Out:
# 샘플 수: 6033  |  정상: 4475  |  이상지질혈증: 1558

# %% [markdown]
# ## 3. Optuna 최적 파라미터 설정

# %%
best_params = {
    "n_estimators": 487,
    "learning_rate": 0.08927180304353628,
    "max_depth": 7,
    "min_child_weight": 6,
    "subsample": 0.6624074561769746,
    "colsample_bytree": 0.662397808134481,
    "gamma": 0.05808361216819946,
    "reg_alpha": 0.8661761457749352,
    "reg_lambda": 2.002787529358022,
    "scale_pos_weight": ratio,
    "eval_metric": "auc",
    "early_stopping_rounds": 50,
    "random_state": RANDOM_STATE,
    "n_jobs": -1,
    "verbosity": 0,
}
print("파라미터 설정 완료")
# Out:
# 파라미터 설정 완료

# %% [markdown]
# ## 4. Stratified 5-Fold CV — OOF proba & SHAP 수집

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=RANDOM_STATE)
oof_proba = np.zeros(len(y))
shap_values = np.zeros(X.shape)
fold_scores = []

print("=" * 55)
for fold, (tr_idx, val_idx) in enumerate(skf.split(X, y), 1):
    X_tr, X_val = X.iloc[tr_idx], X.iloc[val_idx]
    y_tr, y_val = y.iloc[tr_idx], y.iloc[val_idx]

    model = xgb.XGBClassifier(**best_params)
    model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], verbose=False)

    proba = model.predict_proba(X_val)[:, 1]
    oof_proba[val_idx] = proba

    explainer = shap.TreeExplainer(model)
    shap_values[val_idx] = explainer.shap_values(X_val)

    pred = (proba >= THRESHOLD).astype(int)
    fold_scores.append(
        {
            "fold": fold,
            "auc": roc_auc_score(y_val, proba),
            "f1": f1_score(y_val, pred),
            "recall": recall_score(y_val, pred),
        }
    )
    print(
        f"  Fold {fold} | AUC: {fold_scores[-1]['auc']:.4f} | "
        f"Recall: {fold_scores[-1]['recall']:.4f} | F1: {fold_scores[-1]['f1']:.4f}"
    )

scores_df = pd.DataFrame(fold_scores)
print("=" * 55)
print(
    f"  평균   | AUC: {scores_df.auc.mean():.4f} | "
    f"Recall: {scores_df.recall.mean():.4f} | F1: {scores_df.f1.mean():.4f}"
)
# Out:
# =======================================================
#   Fold 1 | AUC: 0.7950 | Recall: 0.7949 | F1: 0.5573
#   Fold 2 | AUC: 0.7848 | Recall: 0.8141 | F1: 0.5676
#   Fold 3 | AUC: 0.7934 | Recall: 0.8205 | F1: 0.5639
#   Fold 4 | AUC: 0.8172 | Recall: 0.8585 | F1: 0.5779
#   Fold 5 | AUC: 0.7859 | Recall: 0.8907 | F1: 0.5630
# =======================================================
#   평균   | AUC: 0.7952 | Recall: 0.8357 | F1: 0.5659

# %% [markdown]
# ## OOF proba 저장 (.npy)

# %%
os.makedirs(NPY_DIR, exist_ok=True)
npy_path = os.path.join(NPY_DIR, "oof_proba_HL_xgboost_optuna_shap.npy")
oof_array = np.stack([oof_proba, y.values], axis=1)  # col0: proba, col1: y_true
np.save(npy_path, oof_array)
print(f"저장 완료 → {npy_path}")
print(f"shape: {oof_array.shape}  (col0: oof_proba, col1: y_true)")
loaded = np.load(npy_path)
print(f"로드 확인: shape={loaded.shape}, 일치={np.allclose(oof_array, loaded)}")
# Out:
# 저장 완료 → /Users/Jiyeon/Desktop/final_project/ML/outputs/oof/oof_proba_HL_xgboost_optuna_shap.npy
# shape: (6033, 2)  (col0: oof_proba, col1: y_true)
# 로드 확인: shape=(6033, 2), 일치=True

# %% [markdown]
# ---
# # SHAP 분석

# %% [markdown]
# ## 5. SHAP Feature Importance (mean |SHAP|)

# %%
mean_shap = pd.Series(np.abs(shap_values).mean(axis=0), index=X.columns).sort_values(ascending=False)

plt.figure(figsize=(8, 6))
mean_shap.head(20)[::-1].plot(kind="barh", color="steelblue")
plt.title("SHAP Feature Importance Top 20 (mean |SHAP|) — 이상지질혈증 XGBoost Optuna · OOF 전체")
plt.xlabel("mean |SHAP value|")
plt.tight_layout()
plt.show()

print("[SHAP Feature Importance Top 15]")
for i, (feat, val) in enumerate(mean_shap.head(15).items(), 1):
    print(f"  {i:2d}. {feat}: {val:.4f}")
# Out:
# [SHAP Feature Importance Top 15]
#    1. 나이: 0.9061
#    2. BMI: 0.1902
#    3. 키: 0.1388
#    4. 체중: 0.1053
#    5. 고지혈증가족력_모: 0.0685
#    6. 고지혈증가족력_형제: 0.0543
#    7. 고혈압가족력_형제: 0.0543
#    8. 성별: 0.0468
#    9. 고혈압가족력_모: 0.0388
#   10. 음주빈도_enc: 0.0374
#   11. 걷기일수: 0.0349
#   12. 음주량_enc: 0.0304
#   13. 당뇨가족력_형제: 0.0304
#   14. 고혈압가족력_부: 0.0249
#   15. 직업_주부학생: 0.0236

# %% [markdown]
# ## 6. SHAP Summary Plot (Beeswarm)

# %%
shap.summary_plot(shap_values, X, plot_type="dot", max_display=20, show=False)
plt.title("SHAP Summary (Beeswarm) — 이상지질혈증 XGBoost Optuna · OOF 전체", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 7. SHAP Dependence Plot — 상위 피처 (나이, BMI)

# %%
top2 = mean_shap.head(2).index.tolist()

fig, axes = plt.subplots(1, 2, figsize=(13, 5))
for ax, feat in zip(axes, top2):
    shap.dependence_plot(feat, shap_values, X, ax=ax, show=False)
    ax.set_title(f"SHAP Dependence — {feat} (Optuna)")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. SHAP Dependence Plot — 고지혈증 가족력 3종

# %%
fh_feats = ["고지혈증가족력_형제", "고지혈증가족력_모", "고지혈증가족력_부"]
# 존재하는 피처만 사용
fh_feats = [f for f in fh_feats if f in X.columns]

fig, axes = plt.subplots(1, len(fh_feats), figsize=(5 * len(fh_feats), 5))
if len(fh_feats) == 1:
    axes = [axes]
for ax, feat in zip(axes, fh_feats):
    shap.dependence_plot(feat, shap_values, X, ax=ax, show=False)
    ax.set_title(f"SHAP Dependence — {feat}")
plt.suptitle("고지혈증 가족력 SHAP Dependence", fontsize=12)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. SHAP Waterfall — 고위험 / 저위험 샘플 개별 해석

# %%
explainer_last = shap.TreeExplainer(model)

high_idx = np.argsort(oof_proba)[::-1][0]
low_idx = np.argsort(oof_proba)[0]

for idx, label in [(high_idx, "고위험"), (low_idx, "저위험")]:
    shap_exp = explainer_last(X.iloc[[idx]])
    print(f"[{label}] 샘플 index={idx} | proba={oof_proba[idx]:.4f} | 실제={y.iloc[idx]}")
    shap.waterfall_plot(shap_exp[0], show=False)
    plt.title(f"SHAP Waterfall — {label} 샘플 (proba={oof_proba[idx]:.3f})")
    plt.tight_layout()
    plt.show()
# Out:
# [고위험] 샘플 index=4317 | proba=0.9199 | 실제=1
# [저위험] 샘플 index=3908 | proba=0.0085 | 실제=0

# %% [markdown]
# ## 10. Baseline gain vs Optuna SHAP 비교

# %%
# Baseline gain importance (threshold 조정 단계)
baseline_gain = {
    "나이": 39.0,
    "고지혈증가족력_형제": 12.6,
    "직업_주부학생": 8.4,
    "성별": 8.3,
    "BMI": 7.7,
    "직업_농림어업": 7.3,
    "고혈압가족력_모": 6.9,
    "고지혈증가족력_모": 6.3,
    "고혈압가족력_형제": 6.1,
    "체중": 5.4,
    "당뇨가족력_부": 5.3,
    "당뇨가족력_형제": 5.2,
    "직업_관리전문": 5.1,
    "키": 4.9,
    "현재흡연": 4.8,
}
max_gain = max(baseline_gain.values())
baseline_norm = {k: v / max_gain for k, v in baseline_gain.items()}

max_shap = mean_shap.max()
shap_norm = (mean_shap / max_shap).head(15).to_dict()

common = sorted(set(baseline_norm.keys()) & set(shap_norm.keys()), key=lambda x: shap_norm.get(x, 0), reverse=True)

fig, ax = plt.subplots(figsize=(9, 6))
x = np.arange(len(common))
w = 0.35
ax.barh(x - w / 2, [baseline_norm[f] for f in common], w, label="Baseline (gain, 정규화)", color="#6b7599", alpha=0.8)
ax.barh(
    x + w / 2, [shap_norm[f] for f in common], w, label="Optuna SHAP (mean|shap|, 정규화)", color="steelblue", alpha=0.9
)
ax.set_yticks(x)
ax.set_yticklabels(common)
ax.set_xlabel("Normalized Importance")
ax.set_title("Feature Importance 비교 — Baseline gain vs Optuna SHAP")
ax.legend()
ax.grid(axis="x", alpha=0.3)
plt.tight_layout()
plt.show()

print(f"{'Feature':<22} {'Baseline':>10} {'SHAP':>10}")
print("-" * 45)
for feat in common:
    print(f"{feat:<22} {baseline_norm[feat]:>10.4f} {shap_norm[feat]:>10.4f}")
# Out:
# Feature                  Baseline       SHAP
# ---------------------------------------------
# 나이                         1.0000     1.0000
# BMI                        0.1974     0.2099
# 키                          0.1256     0.1532
# 체중                         0.1385     0.1163
# 고지혈증가족력_모                  0.1615     0.0756
# 고지혈증가족력_형제                 0.3231     0.0600
# 고혈압가족력_형제                  0.1564     0.0599
# 성별                         0.2128     0.0516
# 고혈압가족력_모                   0.1769     0.0428
# 당뇨가족력_형제                   0.1333     0.0335
# 직업_주부학생                    0.2154     0.0260

# %% [markdown]
# ## 11. DB 로그 저장

# %%
import sys

sys.path.insert(0, "/Users/Jiyeon/Desktop/final_project/ML")
from model_logger import ModelLogger

logger = ModelLogger("/Users/Jiyeon/Desktop/final_project/ML/model_result.db")

pred_oof = (oof_proba >= THRESHOLD).astype(int)
cm = confusion_matrix(y, pred_oof)

run_id = logger.log_run(
    target_var="이상지질혈증",
    model_name="XGBoost",
    stage="optuna_shap",
    hyperparams={
        "learning_rate": best_params["learning_rate"],
        "max_depth": best_params["max_depth"],
        "n_estimators": best_params["n_estimators"],
        "class_weight": {0: 1.0, 1: round(ratio, 4)},
        "min_child_weight": best_params["min_child_weight"],
        "subsample": best_params["subsample"],
        "colsample_bytree": best_params["colsample_bytree"],
        "gamma": best_params["gamma"],
        "reg_alpha": best_params["reg_alpha"],
        "reg_lambda": best_params["reg_lambda"],
    },
    data_info={
        "feature_count": X.shape[1],
        "train_test_split": "5-Fold CV",
        "scaling_method": "None",
    },
    oof_metrics={
        "accuracy": float((pred_oof == y).mean()),
        "recall": recall_score(y, pred_oof),
        "precision": precision_score(y, pred_oof),
        "f1_score": f1_score(y, pred_oof),
        "auc_roc": roc_auc_score(y, oof_proba),
        "cm": cm.tolist(),
    },
    fold_scores=scores_df.to_dict("records"),
    top_features=mean_shap.head(15).to_dict(),
    note="Optuna 최적 파라미터 기준 SHAP 분석. top_features = SHAP mean|shap| 기준.",
)

print(f"저장 완료 → run_id: {run_id}")
print()
print("[전체 실험 목록]")
print(logger.compare_runs().to_string(index=False))
# Out:
# [ModelLogger] 저장 완료 | run_id=10 | 이상지질혈증 XGBoost (optuna_shap)
# 저장 완료 → run_id: 10
#
# [전체 실험 목록]
#  run_id          created_at target_var model_name          stage  auc_roc   recall  precision  f1_score  accuracy
#      10 2026-05-15 19:09:58     이상지질혈증    XGBoost    optuna_shap 0.788701 0.835687   0.427867  0.565964  0.668987
#       9 2026-05-15 19:00:15     이상지질혈증    XGBoost         optuna 0.803302 0.879974   0.421328  0.569825  0.656887
#       8 2026-05-15 18:06:03     이상지질혈증    XGBoost threshold_0.45 0.787916 0.842747   0.412893  0.554242  0.649925
#       7 2026-05-15 17:34:49         당뇨    XGBoost    optuna_shap 0.790561 0.839704   0.246829  0.381513  0.634013
#       6 2026-05-15 17:24:13         당뇨    XGBoost         optuna 0.804071 0.831073   0.266403  0.403472  0.669650
#       5 2026-05-15 17:02:27         당뇨    XGBoost threshold_0.45 0.783068 0.816276   0.253446  0.386795  0.652080
#       4 2026-05-15 16:25:48        고혈압    XGBoost    optuna_shap 0.859112 0.826190   0.542399  0.654871  0.757500
#       3 2026-05-15 16:22:42        고혈압    XGBoost    optuna_shap 0.859112 0.826190   0.542399  0.654871  0.757500
#       2 2026-05-15 15:55:46        고혈압    XGBoost         optuna 0.859112 0.826190   0.542399  0.654871  0.757500
#       1 2026-05-15 15:30:15        고혈압    XGBoost threshold_0.55 0.853083 0.771429   0.561769  0.650113  0.768772
